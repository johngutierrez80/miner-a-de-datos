# %% [markdown]
# <a href="https://colab.research.google.com/github/johngutierrez80/miner-a-de-datos/blob/main/nuevo_feminicidiosColombia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url="https://raw.githubusercontent.com/johngutierrez80/miner-a-de-datos/main/Feminicidios.csv"
df =pd.read_csv(url)

# %% [markdown]
# https://joserzapata.github.io/courses/python-ciencia-datos/visualizacion/

# %%
df
# Out:
#      ACUSACION  ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO  \
# 0           NO           2010          2010        2010
# 1           NO           2011          2011        2011
# 2           NO           2011          2011        2011
# 3           NO           2012          2012        2012
# 4           NO           2012          2012        2012
# ...        ...            ...           ...         ...
# 3585        SI           2021          2021        2021
# 3586        SI           2021          2021        2021
# 3587        SI           2021          2021        2021
# 3588        SI           2021          2021        2021
# 3589        SI           2021          2022        2021
#
#      ATIPICIDAD_INEXISTENCIA CAPTURA CONDENA CONEXO  \
# 0                         NO      NO      NO     NO
# 1                         NO      NO      NO     NO
# 2                         NO      NO      NO     NO
# 3                         NO      NO      NO     NO
# ...

# %%
from os import path
path='C:\Mineria\feminicidios_Colombia'
df.to_csv(path)

# %%
df.dtypes
print(df.dtypes)
# Out:
# ACUSACION                     object
# ANIO_DENUNCIA                  int64
# ANIO_ENTRADA                   int64
# ANIO_HECHO                     int64
# ATIPICIDAD_INEXISTENCIA       object
# CAPTURA                       object
# CONDENA                       object
# CONEXO                        object
# DELITO                        object
# DEPARTAMENTO                  object
# ESTADO_NOTICIA                object
# ETAPA                         object
# GRUPO_DELITO                  object
# GRUPO_EDAD_VICTIMA            object
# HECHO                         object
# HOMICIDIO_DOLOSO_CONSUMADO    object
# IMPUTACION                    object
# LEY                           object
# MUNICIPIO                     object
# PAIS                          object
# PAIS_NACIMIENTO               object
# RUPTURA                       object
# SECCIONAL                     object
# SEXO_VICTIMA                  object
# TOTAL_VICTIMAS                 int64
# dtype: object

# %%
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Amazonas'],1)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Antioquia'],2)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Arauca'],3)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Archipiélago de San Andrés, Providencia y Santa Catalina'],4)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Atlántico'],5)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['BOGOTÁ, D. C.'],6)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Bolívar'],7)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Boyaca'],8)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Caldas'],9)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Caquetá'],10)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Casanare'],11)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Cauca'],12)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Cesar'],13)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Chocó'],14)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Cundinamarca'],15)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Córdoba'],16)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Guainía'],17)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Guaviare'],18)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Huila'],19)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['La Guajira'],20)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Magdalena'],21)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Meta'],22)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Nariño',],23)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Norte de Santander'],24)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Putumayo'],25)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Quindío'],26)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Risaralda'],27)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Santander'],28)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Sucre'],29)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Tolima'],30)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Valle del Cauca'],31)
df['DEPARTAMENTO']=df['DEPARTAMENTO'].replace(['Vaupés'],32)

df['HOMICIDIO_DOLOSO_CONSUMADO']=df['HOMICIDIO_DOLOSO_CONSUMADO'].replace(['SI'],1)
df['HOMICIDIO_DOLOSO_CONSUMADO']=df['HOMICIDIO_DOLOSO_CONSUMADO'].replace(['NO'],0)

df['CONDENA']=df['CONDENA'].replace(['SI'],1)
df['CONDENA']=df['CONDENA'].replace(['NO'],0)
df['ACUSACION']=df['ACUSACION'].replace(['SI'],1)
df['ACUSACION']=df['ACUSACION'].replace(['NO'],0)

df['CAPTURA']=df['CAPTURA'].replace(['SI'],1)
df['CAPTURA']=df['CAPTURA'].replace(['NO'],0)

df['CONEXO']=df['CONEXO'].replace(['SI'],1)
df['CONEXO']=df['CONEXO'].replace(['NO'],0)

df['RUPTURA']=df['RUPTURA'].replace(['SI'],1)
df['RUPTURA']=df['RUPTURA'].replace(['NO'],0)

df['HECHO']=df['HECHO'].replace(['SI'],1)
df['HECHO']=df['HECHO'].replace(['NO'],0)

df['ATIPICIDAD_INEXISTENCIA']=df['ATIPICIDAD_INEXISTENCIA'].replace(['SI'],1)
df['ATIPICIDAD_INEXISTENCIA']=df['ATIPICIDAD_INEXISTENCIA'].replace(['NO'],0)

df['ESTADO_NOTICIA']=df['ESTADO_NOTICIA'].replace(['ACTIVO'],1)
df['ESTADO_NOTICIA']=df['ESTADO_NOTICIA'].replace(['INACTIVO'],0)

df['ETAPA']=df['ETAPA'].replace(['INDAGACIÓN'],1)
df['ETAPA']=df['ETAPA'].replace(['JUICIO'],2)
df['ETAPA']=df['ETAPA'].replace(['EJECUCIÓN DE PENAS'],3)
df['ETAPA']=df['ETAPA'].replace(['INVESTIGACIÓN'],4)
df['ETAPA']=df['ETAPA'].replace(['QUERELLABLE'],5)
df['ETAPA']=df['ETAPA'].replace(['TERMINACIÓN ANTICIPADA'],6)

df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['PRIMERA INFANCIA 0 - 5'],1)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['INFANCIA 6 - 11'],2)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['PRE-ADOLESCENTE 12 - 13'],3)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['ADOLESCENTE 14 - 17'],4)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['JUVENTUD 18 - 28'],5)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['ADULTEZ 29 - 59'],6)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['ADULTO MAYOR DE 60'],7)
df['GRUPO_EDAD_VICTIMA']=df['GRUPO_EDAD_VICTIMA'].replace(['SIN DATO'],8)

df['IMPUTACION']=df['IMPUTACION'].replace(['SI'],1)
df['IMPUTACION']=df['IMPUTACION'].replace(['NO'],0)

# %%
df.describe()
# Out:
#          ACUSACION  ANIO_DENUNCIA  ANIO_ENTRADA   ANIO_HECHO  \
# count  3590.000000    3590.000000   3590.000000  3590.000000
# mean      0.464624    2019.309749   2019.327577  2019.262953
# std       0.498816       2.110592      2.109616     2.145694
# min       0.000000    2010.000000   2010.000000  2010.000000
# 25%       0.000000    2018.000000   2018.000000  2018.000000
# 50%       0.000000    2019.000000   2019.000000  2019.000000
# 75%       1.000000    2021.000000   2021.000000  2021.000000
# max       1.000000    2023.000000   2023.000000  2023.000000
#
#        ATIPICIDAD_INEXISTENCIA      CAPTURA      CONDENA       CONEXO  \
# count              3590.000000  3590.000000  3590.000000  3590.000000
# mean                  0.021727     0.533705     0.339833     0.014485
# std                   0.145811     0.498932     0.473718     0.119494
# min                   0.000000     0.000000     0.000000     0.000000
# ...

# %%
from pandas._libs import missing
#valores nulos por columna
missing_values_count=df.isna().sum()
missing_values_count
# Out:
# ACUSACION                       0
# ANIO_DENUNCIA                   0
# ANIO_ENTRADA                    0
# ANIO_HECHO                      0
# ATIPICIDAD_INEXISTENCIA         0
# CAPTURA                         0
# CONDENA                         0
# CONEXO                          0
# DELITO                          0
# DEPARTAMENTO                    0
# ESTADO_NOTICIA                  0
# ETAPA                           0
# GRUPO_DELITO                    0
# GRUPO_EDAD_VICTIMA              0
# HECHO                           0
# HOMICIDIO_DOLOSO_CONSUMADO      0
# IMPUTACION                      0
# LEY                             0
# MUNICIPIO                       0
# PAIS                            0
# PAIS_NACIMIENTO               318
# RUPTURA                         0
# SECCIONAL                       2
# SEXO_VICTIMA                   38
# TOTAL_VICTIMAS                  0
# dtype: int64

# %%
df.isna().sum()
# Out:
# ACUSACION                       0
# ANIO_DENUNCIA                   0
# ANIO_ENTRADA                    0
# ANIO_HECHO                      0
# ATIPICIDAD_INEXISTENCIA         0
# CAPTURA                         0
# CONDENA                         0
# CONEXO                          0
# DELITO                          0
# DEPARTAMENTO                    0
# ESTADO_NOTICIA                  0
# ETAPA                           0
# GRUPO_DELITO                    0
# GRUPO_EDAD_VICTIMA              0
# HECHO                           0
# HOMICIDIO_DOLOSO_CONSUMADO      0
# IMPUTACION                      0
# LEY                             0
# MUNICIPIO                       0
# PAIS                            0
# PAIS_NACIMIENTO               318
# RUPTURA                         0
# SECCIONAL                       2
# SEXO_VICTIMA                   38
# TOTAL_VICTIMAS                  0
# dtype: int64

# %%
#procesamiento
import pandas as pd
import numpy as np
import datetime as  dt
import missingno as msno

# visualizacion
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
#visualizar cantidad de datos
msno.bar(df);

# %%
#verificar  si algun valor es NaN  en un dataframe de pandas 
df[df.isna().any(1)]
# Out:
# <ipython-input-11-34cede22f1a5>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isna().any(1)]
#       ACUSACION  ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO  \
# 2             0           2011          2011        2011
# 6             0           2013          2013        2013
# 7             0           2013          2013        2013
# 8             0           2014          2014        2013
# 12            0           2014          2014        2014
# ...         ...            ...           ...         ...
# 3487          1           2021          2021        2021
# 3521          1           2021          2021        2021
# 3547          1           2021          2021        2021
# 3556          1           2021          2021        2021
# 3574          1           2021          2021        2021
#
#       ATIPICIDAD_INEXISTENCIA  CAPTURA  CONDENA  CONEXO  \
# ...

# %%
values={"PAIS_NACIMIENTO": "Extranjero"}
df.fillna(value=values,inplace=True)

# %%
df[df.isna().any(1)]
# Out:
# <ipython-input-13-d2acb03cc04c>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isna().any(1)]
#       ACUSACION  ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO  \
# 2             0           2011          2011        2011
# 6             0           2013          2013        2013
# 7             0           2013          2013        2013
# 8             0           2014          2014        2013
# 12            0           2014          2014        2014
# 45            0           2015          2015        2015
# 46            0           2015          2015        2015
# 338           0           2018          2018        2018
# 599           0           2019          2019        2019
# 694           0           2019          2019        2019
# 765           0           2020          2020        2020
# 876           0           2020          2020        2020
# ...

# %%
#valores nulos por columna
missing_values_count=df.isna().sum()
missing_values_count
# Out:
# ACUSACION                      0
# ANIO_DENUNCIA                  0
# ANIO_ENTRADA                   0
# ANIO_HECHO                     0
# ATIPICIDAD_INEXISTENCIA        0
# CAPTURA                        0
# CONDENA                        0
# CONEXO                         0
# DELITO                         0
# DEPARTAMENTO                   0
# ESTADO_NOTICIA                 0
# ETAPA                          0
# GRUPO_DELITO                   0
# GRUPO_EDAD_VICTIMA             0
# HECHO                          0
# HOMICIDIO_DOLOSO_CONSUMADO     0
# IMPUTACION                     0
# LEY                            0
# MUNICIPIO                      0
# PAIS                           0
# PAIS_NACIMIENTO                0
# RUPTURA                        0
# SECCIONAL                      2
# SEXO_VICTIMA                  38
# TOTAL_VICTIMAS                 0
# dtype: int64

# %%
values={"SEXO_VICTIMA": "NO_DECLARA"}
df.fillna(value=values,inplace=True)

# %%
df[df.isna().any(1)]
# Out:
# <ipython-input-16-d2acb03cc04c>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isna().any(1)]
#     ACUSACION  ANIO_DENUNCIA  ANIO_ENTRADA  ANIO_HECHO  \
# 45          0           2015          2015        2015
# 46          0           2015          2015        2015
#
#     ATIPICIDAD_INEXISTENCIA  CAPTURA  CONDENA  CONEXO  \
# 45                        0        0        1       0
# 46                        0        0        1       0
#
#                         DELITO  DEPARTAMENTO  ...  HOMICIDIO_DOLOSO_CONSUMADO  \
# 45  FEMINICIDIO ART. 104A C.P.            15  ...                           0
# 46  FEMINICIDIO ART. 104A C.P.            15  ...                           0
#
#     IMPUTACION      LEY  MUNICIPIO      PAIS  PAIS_NACIMIENTO  RUPTURA  \
# 45           1  Ley 906   ANAPOIMA  Colombia         Colombia        0
# 46           1  Ley 906   ANAPOIMA  Colombia         Colombia        0
#
# ...

# %%
#valores nulos por columna
missing_values_count=df.isna().sum()
missing_values_count
# Out:
# ACUSACION                     0
# ANIO_DENUNCIA                 0
# ANIO_ENTRADA                  0
# ANIO_HECHO                    0
# ATIPICIDAD_INEXISTENCIA       0
# CAPTURA                       0
# CONDENA                       0
# CONEXO                        0
# DELITO                        0
# DEPARTAMENTO                  0
# ESTADO_NOTICIA                0
# ETAPA                         0
# GRUPO_DELITO                  0
# GRUPO_EDAD_VICTIMA            0
# HECHO                         0
# HOMICIDIO_DOLOSO_CONSUMADO    0
# IMPUTACION                    0
# LEY                           0
# MUNICIPIO                     0
# PAIS                          0
# PAIS_NACIMIENTO               0
# RUPTURA                       0
# SECCIONAL                     2
# SEXO_VICTIMA                  0
# TOTAL_VICTIMAS                0
# dtype: int64

# %%
print(df.groupby('PAIS_NACIMIENTO').size())
# Out:
# PAIS_NACIMIENTO
# Chile            1
# Colombia      3121
# Cuba             1
# Curaçao          1
# España           1
# Extranjero     318
# Venezuela      147
# dtype: int64

# %%
print(df.groupby('SEXO_VICTIMA').size())
# Out:
# SEXO_VICTIMA
# FEMENINO      3185
# MASCULINO      367
# NO_DECLARA      38
# dtype: int64

# %%
print(df.groupby('DEPARTAMENTO').size())
# Out:
# DEPARTAMENTO
# 1       4
# 2     404
# 3      36
# 4       8
# 5     136
# 6     500
# 7     144
# 8      64
# 9      68
# 10     41
# 11     58
# 12    149
# 13     85
# 14     52
# 15    145
# 16     76
# 17      2
# 18     14
# 19     81
# 20     34
# 21    154
# 22    118
# 23    102
# 24     71
# 25     59
# 26     49
# 27     58
# 28    160
# 29     48
# 30    196
# 31    471
# 32      3
# dtype: int64

# %%
df.dtypes
print(df.dtypes)
# Out:
# ACUSACION                      int64
# ANIO_DENUNCIA                  int64
# ANIO_ENTRADA                   int64
# ANIO_HECHO                     int64
# ATIPICIDAD_INEXISTENCIA        int64
# CAPTURA                        int64
# CONDENA                        int64
# CONEXO                         int64
# DELITO                        object
# DEPARTAMENTO                   int64
# ESTADO_NOTICIA                 int64
# ETAPA                          int64
# GRUPO_DELITO                  object
# GRUPO_EDAD_VICTIMA             int64
# HECHO                          int64
# HOMICIDIO_DOLOSO_CONSUMADO     int64
# IMPUTACION                     int64
# LEY                           object
# MUNICIPIO                     object
# PAIS                          object
# PAIS_NACIMIENTO               object
# RUPTURA                        int64
# SECCIONAL                     object
# SEXO_VICTIMA                  object
# TOTAL_VICTIMAS                 int64
# dtype: object

# %%
print(df.groupby('MUNICIPIO').size())
# Out:
# MUNICIPIO
# ACACÍAS          3
# ACANDÍ           1
# ACEVEDO          4
# ACHÍ             1
# AGRADO           1
#                 ..
# ZARAGOZA         1
# ZARZAL           2
# ZIPAQUIRÁ        6
# ZONA BANANERA    4
# ÚTICA            1
# Length: 558, dtype: int64

# %%
print(df.groupby('ACUSACION').size())
print(df.groupby('CAPTURA').size())
print(df.groupby('CONDENA').size())
print(df.groupby('ATIPICIDAD_INEXISTENCIA').size())
# Out:
# ACUSACION
# 0    1922
# 1    1668
# dtype: int64
# CAPTURA
# 0    1674
# 1    1916
# dtype: int64
# CONDENA
# 0    2370
# 1    1220
# dtype: int64
# ATIPICIDAD_INEXISTENCIA
# 0    3512
# 1      78
# dtype: int64

# %%
f,ax=plt.subplots(figsize=(20,10))
corr=df.corr('pearson')
dataplot=sns.heatmap(df.corr(),cmap="Greens", annot=True)
# Out:
# <ipython-input-24-a2055147ad8c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr('pearson')
# <ipython-input-24-a2055147ad8c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot=sns.heatmap(df.corr(),cmap="Greens", annot=True)

# %%
plt.figure(figsize=(15,5))
plt.title("¿Cúal es el departamento con mayor número de feminicidios y sexo de la víctima")
ax=sns.countplot(x='DEPARTAMENTO',hue='SEXO_VICTIMA', data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=50, ay='right',FontSize=8)
#plt.right_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("¿Cúal es sexo y grupo de edad  de las victimas con mayor incidencia  en los feminicidios en colombia")
ax=sns.countplot(x='SEXO_VICTIMA',hue='GRUPO_EDAD_VICTIMA', data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=50, ay='right',FontSize=8)
#plt.right_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("¿Cúal es sexo y grupo de edad  de las victimas con mayor incidencia  en los feminicidios en colombia")
ax=sns.countplot(x='ACUSACION',hue='GRUPO_EDAD_VICTIMA', data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=50, ay='right',FontSize=8)
#plt.right_layout()
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title("¿QUE CANTIDAD DE FEMINICIDIOS HAN SIDO CAUSA DE VIOLENCIA PREMEDITADA")
ax=sns.countplot(x='HOMICIDIO_DOLOSO_CONSUMADO',hue='TOTAL_VICTIMAS', data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=50, ay='right',FontSize=8)
#plt.right_layout()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("Estado de las condenas de acuerdo al año  del delito")
ax=sns.countplot(x='ANIO_HECHO',hue='CONDENA', data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=50, ay='right',FontSize=8)
#plt.right_layout()
plt.show()

# %%
plt.figure(figsize=(20,5))
plt,plt.title('¿CUALES DEPARTAMENTOS DE COLOMBIA TIENEN MAS  FEMINICIDIOS?')
ax=sns.countplot(x='DEPARTAMENTO', data=df)

# %%
plt.scatter(df['ANIO_HECHO'],df['TOTAL_VICTIMAS'])
plt.xlabel('Año de hecho')
plt.ylabel('total de victimas')
plt.title('TOTAL DE VICTIMAS POR AÑOS')
plt.show()

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x='ETAPA', data=df)
plt.show()

# %% [markdown]
# (['INDAGACIÓN']1,(['JUICIO']2),(['EJECUCIÓN DE PENAS'],3)](['INVESTIGACIÓN'],4),(['QUERELLABLE'],5),(['TERMINACIÓN ANTICIPADA'],6)
